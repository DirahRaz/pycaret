00:00:00","1958-06-01T00:00:00","1958-07-01T00:00:00","1958-08-01T00:00:00","1958-09-01T00:00:00","1958-10-01T00:00:00","1958-11-01T00:00:00","1958-12-01T00:00:00","1959-01-01T00:00:00","1959-02-01T00:00:00","1959-03-01T00:00:00","1959-04-01T00:00:00","1959-05-01T00:00:00","1959-06-01T00:00:00","1959-07-01T00:00:00","1959-08-01T00:00:00","1959-09-01T00:00:00","1959-10-01T00:00:00","1959-11-01T00:00:00","1959-12-01T00:00:00","1960-01-01T00:00:00","1960-02-01T00:00:00","1960-03-01T00:00:00","1960-04-01T00:00:00","1960-05-01T00:00:00","1960-06-01T00:00:00","1960-07-01T00:00:00","1960-08-01T00:00:00","1960-09-01T00:00:00","1960-10-01T00:00:00","1960-11-01T00:00:00","1960-12-01T00:00:00"],"xaxis":"x","y":[112.0,118.0,132.0,129.0,121. ...

# %%
# extract month and year from dates
import numpy as np
data['Month'] = [i.month for i in data['Date']]
data['Year'] = [i.year for i in data['Date']]
# create a sequence of numbers
data['Series'] = np.arange(1,len(data)+1)
# drop unnecessary columns and re-arrange
data.drop(['Date', 'MA12'], axis=1, inplace=True)
data = data[['Series', 'Year', 'Month', 'Passengers']] 
# check the head of the dataset
data.head()
# Out:
#    Series  Year  Month  Passengers
# 0       1  1949      1         112
# 1       2  1949      2         118
# 2       3  1949      3         132
# 3       4  1949      4         129
# 4       5  1949      5         121

# %%
# split data into train-test set
train = data[data['Year'] < 1960]
test = data[data['Year'] >= 1960]
# check shape
train.shape, test.shape
# Out:
# ((132, 4), (12, 4))

# %%
# import the regression module
from pycaret.regression import *
# initialize setup
s = setup(data = train, test_data = test, target = 'Passengers', fold_strategy = 'timeseries', numeric_features = ['Year', 'Series'], fold = 3, transform_target = True, session_id = 123)
# Out:
# <style type="text/css">
# #T_e3a28_row54_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3a28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3a28_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e3a28_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3a28_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3a28_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e3a28_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3a28_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e3a28_row1_col1" class="data row1 col1" >Passengers</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3a28_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_e3a28_row2_col1" class="data row2 col1" >(132, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3a28_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_e3a28_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3a28_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_e3a28_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3a28_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_e3a28_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3a28_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_e3a28_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3a28_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_e3a28_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3a28_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_e3a28_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3a28_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_e3a28_row9_col1" class="data row9 col1" >(132, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e3a28_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_e3a28_row10_col1" class="data row10 col1" >(12, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e3a28_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_e3a28_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e3a28_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_e3a28_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e3a28_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_e3a28_row13_col1" class="data row13 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e3a28_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_e3a28_row14_col1" class="data row14 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e3a28_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_e3a28_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e3a28_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_e3a28_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e3a28_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_e3a28_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e3a28_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_e3a28_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e3a28_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_e3a28_row19_col1" class="data row19 col1" >a4a8</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e3a28_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_e3a28_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e3a28_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_e3a28_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e3a28_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_e3a28_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e3a28_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_e3a28_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e3a28_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_e3a28_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e3a28_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_e3a28_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e3a28_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_e3a28_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e3a28_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_e3a28_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e3a28_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_e3a28_row28_col1" class="data row28 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e3a28_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_e3a28_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3a28_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_e3a28_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_e3a28_row30_col1"
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 4>()
#       2 from pycaret.regression import *
#       3 # initialize setup
# ----> 4 s = setup(data = train, test_data = test, target = 'Passengers', fold_strategy = 'timeseries', numeric_features = ['Year', 'Series'], fold = 3, transform_target = True, session_id = 123)
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\regression.py:571, in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     568 if log_plots == True:
#     569     log_plots = ["residuals", "error", "feature"]
# --> 571 return pycaret.internal.tabular.setup(
#     572     ml_usecase="regression",
#     573     available_plots=available_plots,
#     574     data=data,
#     575     target=target,
#     576     train_size=train_size,
#     577     test_data=test_data,
#     578     preprocess=preprocess,
#     579     imputation_type=imputation_type,
#     580     iterative_imputation_iters=iterative_imputation_iters,
#     581     categorical_features=categorical_features,
#     582     categorical_imputation=categorical_imputation,
#     583     categorical_iterative_imputer=categorical_iterative_imputer,
#     584     ordinal_features=ordinal_features,
#     585     high_cardinality_features=high_cardinality_features,
#     586     high_cardinality_method=high_cardinality_method,
#     587     numeric_features=numeric_features,
#     588     numeric_imputation=numeric_imputation,
#     589     numeric_iterative_imputer=numeric_iterative_imputer,
#     590     date_features=date_features,
#     591     ignore_features=ignore_features,
#     592     normalize=normalize,
#     593     normalize_method=normalize_method,
#     594     transformation=transformation,
#     595     transformation_method=transformation_method,
#     596     handle_unknown_categorical=handle_unknown_categorical,
#     597     unknown_categorical_method=unknown_categorical_method,
#     598     pca=pca,
#     599     pca_method=pca_method,
#     600     pca_components=pca_components,
#     601     ignore_low_variance=ignore_low_variance,
#     602     combine_rare_levels=combine_rare_levels,
#     603     rare_level_threshold=rare_level_threshold,
#     604     bin_numeric_features=bin_numeric_features,
#     605     remove_outliers=remove_outliers,
#     606     outliers_threshold=outliers_threshold,
#     607     remove_multicollinearity=remove_multicollinearity,
#     608     multicollinearity_threshold=multicollinearity_threshold,
#     609     remove_perfect_collinearity=remove_perfect_collinearity,
#     610     create_clusters=create_clusters,
#     611     cluster_iter=cluster_iter,
#     612     polynomial_features=polynomial_features,
#     613     polynomial_degree=polynomial_degree,
#     614     trigonometry_features=trigonometry_features,
#     615     polynomial_threshold=polynomial_threshold,
#     616     group_features=group_features,
#     617     group_names=group_names,
#     618     feature_selection=feature_selection,
#     619     feature_selection_threshold=feature_selection_threshold,
#     620     feature_selection_method=feature_selection_method,
#     621     feature_interaction=feature_interaction,
#     622     feature_ratio=feature_ratio,
#     623     interaction_threshold=interaction_threshold,
#     624     transform_target=transform_target,
#     625     transform_target_method=transform_target_method,
#     626     data_split_shuffle=data_split_shuffle,
#     627     data_split_stratify=data_split_stratify,
#     628     fold_strategy=fold_strategy,
#     629     fold=fold,
#     630     fold_shuffle=fold_shuffle,
#     631     fold_groups=fold_groups,
#     632     n_jobs=n_jobs,
#     633     use_gpu=use_gpu,
#     634     custom_pipeline=custom_pipeline,
#     635     html=html,
#     636     session_id=session_id,
#     637     log_experiment=log_experiment,
#     638     experiment_name=experiment_name,
#     639     log_plots=log_plots,
#     640     log_profile=log_profile,
#     641     log_data=log_data,
#     642     silent=silent,
#     643     verbose=verbose,
#     644     profile=profile,
#     645     profile_kwargs=profile_kwargs,
#     646 )
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\pycaret\internal\tabular.py:1745, in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1742 logger.info(f"master_model_container: {len(master_model_container)}")
#    1743 logger.info(f"display_container: {len(display_container)}")
# -> 1745 logger.info(str(prep_pipe))
#    1746 logger.info("setup() succesfully completed......................................")
#    1748 gc.collect()
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\base.py:279, in BaseEstimator.__repr__(self, N_CHAR_MAX)
#     271 # use ellipsis for sequences with a lot of elements
#     272 pp = _EstimatorPrettyPrinter(
#     273     compact=True,
#     274     indent=1,
#     275     indent_at_name=True,
#     276     n_max_elements_to_show=N_MAX_ELEMENTS_TO_SHOW,
#     277 )
# --> 279 repr_ = pp.pformat(self)
#     281 # Use bruteforce ellipsis when there are a lot of non-blank characters
#     282 n_nonblank = len("".join(repr_.split()))
#
# File ~\anaconda3\envs\pycaret\lib\pprint.py:157, in PrettyPrinter.pformat(self, object)
#     155 def pformat(self, object):
#     156     sio = _StringIO()
# --> 157     self._format(object, sio, 0, 0, {}, 0)
#     158     return sio.getvalue()
#
# File ~\anaconda3\envs\pycaret\lib\pprint.py:174, in PrettyPrinter._format(self, object, stream, indent, allowance, context, level)
#     172     self._readable = False
#     173     return
# --> 174 rep = self._repr(object, context, level)
#     175 max_width = self._width - indent - allowance
#     176 if len(rep) > max_width:
#
# File ~\anaconda3\envs\pycaret\lib\pprint.py:454, in PrettyPrinter._repr(self, object, context, level)
#     453 def _repr(self, object, context, level):
# --> 454     repr, readable, recursive = self.format(object, context.copy(),
#     455                                             self._depth, level)
#     456     if not readable:
#     457         self._readable = False
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\_pprint.py:189, in _EstimatorPrettyPrinter.format(self, object, context, maxlevels, level)
#     188 def format(self, object, context, maxlevels, level):
# --> 189     return _safe_repr(
#     190         object, context, maxlevels, level, changed_only=self._changed_only
#     191     )
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\_pprint.py:452, in _safe_repr(object, context, maxlevels, level, changed_only)
#     448 for k, v in items:
#     449     krepr, kreadable, krecur = saferepr(
#     450         k, context, maxlevels, level, changed_only=changed_only
#     451     )
# --> 452     vrepr, vreadable, vrecur = saferepr(
#     453         v, context, maxlevels, level, changed_only=changed_only
#     454     )
#     455     append("%s=%s" % (krepr.strip("'"), vrepr))
#     456     readable = readable and kreadable and vreadable
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\_pprint.py:419, in _safe_repr(object, context, maxlevels, level, changed_only)
#     417 level += 1
#     418 for o in object:
# --> 419     orepr, oreadable, orecur = _safe_repr(
#     420         o, context, maxlevels, level, changed_only=changed_only
#     421     )
#     422     append(orepr)
#     423     if not oreadable:
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\utils\_pprint.py:442, in _safe_repr(object, context, maxlevels, level, changed_only)
#     440     params = _changed_params(object)
#     441 else:
# --> 442     params = object.get_params(deep=False)
#     443 components = []
#     444 append = components.append
#
# File ~\anaconda3\envs\pycaret\lib\site-packages\sklearn\base.py:210, in BaseEstimator.get_params(self, deep)
#     208 out = dict()
#     209 for key in self._get_param_names():
# --> 210     value = getattr(self, key)
#     211     if deep and hasattr(value, "get_params"):
#     212         deep_items = value.get_params().items()
#
# AttributeError: 'Simple_Imputer' object has no attribute 'fill_value_categorical'

# %%
from pycaret.classification import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14400/957393446.py in <module>
# ----> 1 from pycaret.classification import *
#
# ModuleNotFoundError: No module named 'pycaret'
